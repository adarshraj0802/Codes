# %%
#binary data format - 
# pickle format is the binary format which tries to perform a surday operation. i.e. serialization.
import pandas as pd

# %%
frame = pd.read_csv(r'C:\Users\adars_000\Downloads\code_pandas1 (1)\examples\ex1.csv')
frame
frame.to_pickle(r'C:\Users\adars_000\Downloads\code_pandas1 (1)\examples\frame_pickle')
frame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_pickle(r'C:\Users\adars_000\Downloads\code_pandas1 (1)\examples\frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# another binary format is HDF5 format.
import numpy as np 
frame = pd.DataFrame({'a': np.random.randn(100)})
frame
# Out:
#            a
# 0  -1.123928
# 1  -0.079135
# 2   1.112339
# 3   1.190442
# 4  -0.869375
# ..       ...
# 95 -0.684820
# 96 -1.096970
# 97  1.179463
# 98  0.401183
# 99  0.410015
#
# [100 rows x 1 columns]

# %%
frame = pd.DataFrame({'a': np.random.randn(10)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] =frame
store

# %%
# Web APIs

import requests   # we are requesting data from a certain URL. 
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'  
resp = requests.get(url)
type(resp)
# Out:
# requests.models.Response

# %%
data = resp.json()
data[2]['repository_url']
# Out:
# 'https://api.github.com/repos/pandas-dev/pandas'

# %%
import pandas as pd 
issues = pd.DataFrame(data)
issues
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
#generally pickle is used in machine learning 
#whereas HDF5 is used in deep learning

# however this is not a hard and fast rule. but it is usually used.

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train.shape
# Out:
# (156, 12)

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_train.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
categorical = titanic_train.dtypes[titanic_train.dtypes == 'object'].index
print(categorical)
titanic_train[categorical]
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# ...

# %%
titanic_train[categorical].describe()
# Out:
#                      Name   Sex  Ticket        Cabin Embarked
# count                 156   156     156           31      155
# unique                156     2     145           28        3
# top     Woolner, Mr. Hugh  male  237736  C23 C25 C27        S
# freq                    1   100       2            2      110

# %%
titanic_train["Ticket"][0:15]
# Out:
# 0            A/5 21171
# 1             PC 17599
# 2     STON/O2. 3101282
# 3               113803
# 4               373450
# 5               330877
# 6                17463
# 7               349909
# 8               347742
# 9               237736
# 10             PP 9549
# 11              113783
# 12           A/5. 2151
# 13              347082
# 14              350406
# Name: Ticket, dtype: object

# %%
titanic_train["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 151    1
# 152    0
# 153    0
# 154    0
# 155    0
# Name: Survived, Length: 156, dtype: int64

# %%
new_Survived = pd.Categorical(titanic_train['Survived'])
new_Survived
# Out:
# [0, 1, 1, 1, 0, ..., 1, 0, 0, 0, 0]
# Length: 156
# Categories (2, int64): [0, 1]

# %%
new_Survived = new_Survived.rename_categories(["Died","Survived"])
new_Survived.describe()
# Out:
#             counts     freqs
# categories
# Died           102  0.653846
# Survived        54  0.346154

# %%
new_Pclass = pd.Categorical(titanic_train['Pclass'], ordered = True)
new_Pclass
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1 < 2 < 3]

# %%
new_Pclass = new_Pclass.rename_categories(['Class 1','Class 2','Class 3'])
new_Pclass.describe()
# Out:
#             counts     freqs
# categories
# Class 1         30  0.192308
# Class 2         30  0.192308
# Class 3         96  0.615385

# %%
new_Pclass
# Out:
# [Class 3, Class 1, Class 3, Class 1, Class 3, ..., Class 1, Class 3, Class 3, Class 3, Class 1]
# Length: 156
# Categories (3, object): [Class 1 < Class 2 < Class 3]

# %%
titanic_train["Pclass1"] = new_Pclass

# %%
new_Cabin = pd.Categorical(titanic_train["Cabin"])
new_Cabin
# Out:
# [NaN, C85, NaN, C123, NaN, ..., C2, NaN, NaN, NaN, NaN]
# Length: 156
# Categories (28, object): [A5, A6, B28, B30, ..., F G73, F2, F33, G6]

# %%
char_Cabin = titanic_train["Cabin"].astype(str)
char_Cabin
# Out:
# 0       nan
# 1       C85
# 2       nan
# 3      C123
# 4       nan
#        ...
# 151      C2
# 152     nan
# 153     nan
# 154     nan
# 155     nan
# Name: Cabin, Length: 156, dtype: object

# %%
import numpy as np
new_Cabin = np.array([cabin[0] for cabin in char_Cabin])
new_Cabin = pd.Categorical(new_Cabin)
new_Cabin.describe()
# Out:
#             counts     freqs
# categories
# A                2  0.012821
# B                5  0.032051
# C               10  0.064103
# D                6  0.038462
# E                3  0.019231
# F                4  0.025641
# G                1  0.006410
# n              125  0.801282

# %%
import pandas as pd
dummy_vector = pd.Series([1, None, 3, None, 7,8])
dummy_vector
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# 3    NaN
# 4    7.0
# 5    8.0
# dtype: float64

# %%
titanic_train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 151    22.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 156, dtype: float64

# %%
# np.where helps you in getting the index wherever the condition is True
missing = np.where(titanic_train['Age'].isnull() == True)
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
index = np.where(titanic_train["Fare"] == max(titanic_train["Fare"]))
titanic_train.loc[index]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked  Pclass1
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S  Class 1
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S  Class 1

# %%
titanic_train.loc[missing].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked  Pclass1
# 5       0      0  330877   8.4583   NaN        Q  Class 3
# 17      0      0  244373  13.0000   NaN        S  Class 2
# 19      0      0    2649   7.2250   NaN        C  Class 3
# 26      0      0    2631   7.2250   NaN        C  Class 3
# 28      0      0  330959   7.8792   NaN        Q  Class 3

# %%
titanic_train["Family"] = titanic_train["SibSp"] + titanic_train["Parch"]

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Pclass1  Family
# 0      0         A/5 21171   7.2500   NaN        S  Class 3       1
# 1      0          PC 17599  71.2833   C85        C  Class 1       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Class 3       0
# ...

# %%
FamilyMax = np.where(titanic_train["Family"] == max(titanic_train["Family"]))
titanic_train.loc[FamilyMax]
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick    male
# 71           72         0       3          Goodwin, Miss. Lillian Amy  female
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked  Pclass1  Family
# 59  11.0      5      2  CA 2144  46.9   NaN        S  Class 3       7
# 71  16.0      5      2  CA 2144  46.9   NaN        S  Class 3       7

# %%
titanic_train.ix[FamilyMax]
# Out:
# C:\Users\adars_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick    male
# 71           72         0       3          Goodwin, Miss. Lillian Amy  female
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked  Pclass1  Family
# 59  11.0      5      2  CA 2144  46.9   NaN        S  Class 3       7
# 71  16.0      5      2  CA 2144  46.9   NaN        S  Class 3       7

# %%
#Pandas - pandas is a package in python. pandas is usually used for file manipulation.
#row manipulation and structure manipulation is possible with pandas.

# Numpy - Numpy is used for array and matrix manipulation.mathematical operation related to algebra, probability can be found in
# in Numpy. 

# Pandas and Numpy is the lifeline for Python.

# %%
labels = ['a','b','c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10,'b':20,'c':30}

print("my_data: ",my_data)
print("arr: ",arr)
print("d: ", d)
print("labels: ", labels)
# Out:
# my_data:  [10, 20, 30]
# arr:  [10 20 30]
# d:  {'a': 10, 'b': 20, 'c': 30}
# labels:  ['a', 'b', 'c']

# %%
pd.Series(my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = my_data, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
print("Holding text labels\n", '-'*20, sep = '')
print(pd.Series(labels))
# Out:
# Holding text labels
# --------------------
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data = [sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4],['CA','CB','CE','CD'])
ser2 = pd.Series([5,6,7,8],['CA','CB','CC','CF'])

# %%
ser2
# Out:
# CA    5
# CB    6
# CC    7
# CD    8
# dtype: int64

# %%
ser3 = ser1 + ser2
ser3
# Out:
# CA    6.0
# CB    8.0
# CC    NaN
# CD    NaN
# CE    NaN
# CF    NaN
# dtype: float64

# %%
import numpy as np
import pandas as pd
from numpy.random import randn as rn
np.random.seed(101)  # random function helps to generate random numbers on standard deviation.
matrix_data = rn(5,4)
row_labels = ['A','B','C','D','E']
column_headings = ['W','X','Y','Z']

df = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings)
print("\nThe data frame looks like\n",'-'*45, sep='')
print(df)
# Out:
# The data frame looks like
# ---------------------------------------------
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
print(df.X)
# Out:
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: X, dtype: float64

# %%
print("\nA column is created by assigning it in relation to an existing column\n",'-'*75, sep='')
df['New'] = df['X']+df['Z']
df['New (Sum of X and Z)'] = df['X']+df['Z']
print(df)
# Out:
# A column is created by assigning it in relation to an existing column
# ---------------------------------------------------------------------------
#           W         X         Y         Z       New  New (Sum of X and Z)
# A  2.706850  0.628133  0.907969  0.503826  1.131958              1.131958
# B  0.651118 -0.319318 -0.848077  0.605965  0.286647              0.286647
# C -2.018168  0.740122  0.528813 -0.589001  0.151122              0.151122
# D  0.188695 -0.758872 -0.933237  0.955057  0.196184              0.196184
# E  0.190794  1.978757  2.605967  0.683509  2.662266              2.662266

# %%
# when we have to remove the row we keep axis = 0, whereas when we have to remove the column we have to keep axis = 1
# there is command called 'inplace' which is false by default. that means that if we remove the column, it doesn't remove
# the column from the original dataframe. However if you write inplace = True then the command will remove the entire column
# permanently.
print("\nA column is dropped by using df.drop() method\n",'-'*55, sep='')
df = df.drop('New', axis=1) # Notice the axis=1 option, axis = 0 is default, so one has to change it to 1
print(df)
# Out:
# A column is dropped by using df.drop() method
# -------------------------------------------------------
#           W         X         Y         Z  New (Sum of X and Z)
# A  2.706850  0.628133  0.907969  0.503826              1.131958
# B  0.651118 -0.319318 -0.848077  0.605965              0.286647
# C -2.018168  0.740122  0.528813 -0.589001              0.151122
# D  0.188695 -0.758872 -0.933237  0.955057              0.196184
# E  0.190794  1.978757  2.605967  0.683509              2.662266

# %%
# del command deletes data from column whereas drop helps to delete from both row and column. 
#

# %%
df =df.drop("New (Sum of X and Z)", axis = 1)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.iloc[1:3,:]
# Out:
#           W         X         Y         Z
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001

# %%
df.iloc[::2,:]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# C -2.018168  0.740122  0.528813 -0.589001
# E  0.190794  1.978757  2.605967  0.683509

# %%
# in case of Loc command it takes the name indexes, hence no inclusion or exclusion
# whereas in case of iloc command it takes the index number.

# %%
df.loc['B','Y']
# Out:
# -0.8480769834036315

# %%
print(df>0)
df[df>0]
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
matrix_data = np.matrix('22,66,140;42,70,148;30,62,125;35,68,160;25,62,152')
row_labels = ['A','B','C','D','E']
column_headings = ['Age', 'Height', 'Weight']

df = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings)
print("\nThe DataFrame\n",'-'*25, sep='')
print(df)
# Out:
# The DataFrame
# -------------------------
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152

# %%
matrix_data
# Out:
# matrix([[ 22,  66, 140],
#         [ 42,  70, 148],
#         [ 30,  62, 125],
#         [ 35,  68, 160],
#         [ 25,  62, 152]])

# %%
M1 = np.matrix('1,2,3;4,5,6;7,8,9')
RL = ['A','B','C']
CH = ['Alpha','Beta','Delta']

df1 = pd.DataFrame(data = M1, index = RL, columns = CH)
print(df1)
# Out:
#    Alpha  Beta  Delta
# A      1     2      3
# B      4     5      6
# C      7     8      9

# %%
df[df['Height']>65 & df['Age']>30]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-6a7c9d7a7076> in <module>
# ----> 1 df[df['Height']>65 & df['Age']>30]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
booldf1 = df['Height']>65
booldf2 = df['Weight']>130

print(df['Height'][(booldf1) & (booldf2)])
# Out:
# A    66
# B    70
# D    68
# Name: Height, dtype: int32

# %%
booldf1 & booldf2
# Out:
# A     True
# B     True
# C    False
# D     True
# E    False
# dtype: bool

# %%
# set and reset indexing
# reset index means that whatever index that we have given is kept and it is also replaced with the default index.

# %%
df.reset_index()
# Out:
#   index  Age  Height  Weight
# 0     A   22      66     140
# 1     B   42      70     148
# 2     C   30      62     125
# 3     D   35      68     160
# 4     E   25      62     152

# %%
# by default the split function always separates the command with 

("Student Teacher Doctor Engineer Plumber").split()
# Out:
# ['Student', 'Teacher', 'Doctor', 'Engineer', 'Plumber']

# %%
df['Profession'] = ("Student Teacher Doctor Engineer Plumber").split()
df
# Out:
#    Age  Height  Weight Profession
# A   22      66     140    Student
# B   42      70     148    Teacher
# C   30      62     125     Doctor
# D   35      68     160   Engineer
# E   25      62     152    Plumber

# %%
outside = ['G1','G1','G1','G2','G2','G2']
inside = [ 1,2,3,1,2,3]

OutIn = list(zip(outside,inside))
OutIn
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
OutIn = pd.MultiIndex.from_tuples(OutIn)
print("\nIndex hierarchy\n",'-'*25, sep='')
print(OutIn)
# Out:
# Index hierarchy
# -------------------------
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
print("\nTuple pairs after the zip and list command\n",'-'*45, sep='')
print(OutIn)
# Out:
# Tuple pairs after the zip and list command
# ---------------------------------------------
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
OutIn = pd.MultiIndex.from_tuples(OutIn)
print("\nIndex hierarchy\n",'-'*25, sep='')
print(OutIn)
# Out:
# Index hierarchy
# -------------------------
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
print("\nCreating DataFrame with multi-index\n",'-'*37, sep='')
np.random.seed(101)
df1 = pd.DataFrame(data=np.round(rn(6,3),2), index= OutIn, columns= ['A','B','C'])
print(df1)
# Out:
# Creating DataFrame with multi-index
# -------------------------------------
#          A     B     C
# G1 1  2.71  0.63  0.91
#    2  0.50  0.65 -0.32
#    3 -0.85  0.61 -2.02
# G2 1  0.74  0.53 -0.59
#    2  0.19 -0.76 -0.93
#    3  0.96  0.19  1.98

# %%
df1.loc['G1'].loc[1].loc['B']
# Out:
# 0.63
